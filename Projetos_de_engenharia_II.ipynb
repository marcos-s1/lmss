# %% [markdown]
# # Codigo relativo à disciplina de projetos de engenharia II
#
# - O codigo tem por objetivo criar um modelo de séries temporais meteorologicas para a cidade de Belém. Para isto, foi utilizado a linguagem de progração Python e os registros presentes no site do Instituto Nacional de Meteorologia.

# %%
# Celula relativa à importação de bibliotecas

import pandas as pd
import numpy as np
import requests
import json
from calendar import monthrange
import numpy as np
from itertools import product
from datetime import date
from itertools import chain
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns

# %% [markdown]
# ## Codigo relativo à extração dos dados

# %%
def allDays(ano, mes):
  '''Retorna uma lista com todos os dias de um determinado mes e ano'''
  
  return ['{:04d}-{:02d}-{:02d}'.format(ano, mes, dia) for dia in range(1, monthrange(ano, mes)[1] + 1)]

# %%
# Estrutura que retornará uma lista com todos os dias entre 1995-01 e 2021-12b

anos = [ano for ano in range(2021, 2023, 1)]

datas_inicio = sorted([ f'{ano}-01-01' for ano in anos ])
datas_fim = sorted([ f'{ano}-12-31' for ano in anos ])

# %%
def getData(string):
  ''' Função que recebe uma String proveniente do site do INMET e retorna somente os dados relativos à cidade de Belem'''
  resultado = json.loads(string.text)

  resultado = pd.DataFrame.from_dict(resultado)
  
  return resultado

def getInfosAboutClimate(data1, data2):
  '''Função que faz uma chamada de API ao site do INMET e retorna o resultado relativo à cidade de Belem'''

  try:
    print(data1, data2)

    link = 'https://apitempo.inmet.gov.br/estacao/{}/{}/A201'.format(data1, data2)

    res = requests.get(link)

    res = getData(res)

    return res
  except:
    pass

# %%
# Montando Um drive para salvar o arquivo em csv

from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
dados = [getInfosAboutClimate(data1, data2) for data1, data2 in zip(datas_inicio, datas_fim)]
# Out:
# 2021-01-01 2021-12-31
# 2022-01-01 2022-12-31

# %%
dados = pd.concat(dados)

# %%
# Salvando os dados no Drive anteriormente montado

dados.to_csv('data.csv', index = False)
# !cp data.csv "drive/My Drive/"

# %%
dados
# Out:
#      DC_NOME PRE_INS TEM_SEN VL_LATITUDE  ... TEM_INS UMD_INS CD_ESTACAO HR_MEDICAO
# 0      BELÉM  1009.4      28   -1.411228  ...      25      90       A201       0000
# 1      BELÉM  1009.8    27.7   -1.411228  ...    24.9      89       A201       0100
# 2      BELÉM  1010.8    27.8   -1.411228  ...    24.7      92       A201       0200
# 3      BELÉM  1010.9    27.8   -1.411228  ...    24.9      90       A201       0300
# 4      BELÉM    None    None   -1.411228  ...    None    None       A201       0400
# ...      ...     ...     ...         ...  ...     ...     ...        ...        ...
# 8755   BELÉM    None    None   -1.411228  ...    None    None       A201       1900
# 8756   BELÉM    None    None   -1.411228  ...    None    None       A201       2000
# 8757   BELÉM    None    None   -1.411228  ...    None    None       A201       2100
# 8758   BELÉM    None    None   -1.411228  ...    None    None       A201       2200
# 8759   BELÉM    None    None   -1.411228  ...    None    None       A201       2300
#
# [17520 rows x 25 columns]

# %%
def getFloat(x):
  '''Função que retorna um float caso o registro tenha essa possibilidade, senão, retorna o proprio registro'''
  try:
    return float(x)
  except:
    return x

# Como a API retorna todos os dados numa string, inclusive numeros, faz-se necessario transformar os dados pertinentes em float
dados_float = dados.copy()

for coluna in dados.drop(columns = ['DC_NOME', 'UF', 'DT_MEDICAO', 'CD_ESTACAO', 'HR_MEDICAO']).columns:
  dados_float[coluna] = dados[coluna].apply(lambda x: getFloat(x) if x is not None else None)

# %% [markdown]
# ## Codigo relativo à analise exploratoria e engenharia de feature

# %%
# !pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip

# %%
# Montando e carregando as informações do Drive

from google.colab import drive
drive.mount('/content/drive')

dados_float = pd.read_csv("drive/My Drive/data.csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas_profiling

profile = pandas_profiling.ProfileReport(dados_float, title="Report de Dados INMET - Belém (Proj. Eng II)", explorative=True)
profile.to_file("profile.html")
# !cp "profile.html" "drive/My Drive/"
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
def info(df):
    '''Funcao que retorna um resumo dos dados, incluindo valores faltantes'''
    df_info = pd.DataFrame({'Colunas': df.columns, 'types': df.dtypes,
                          'NA #': df.isna().sum(),
                          'NA %': (df.isna().sum() / df.shape[0]) * 100})
    df_info = df_info.join(df.describe().T)
    
    return df_info

# %%
info(dados_float)
# Out:
#                    Colunas    types  ...          75%          max
# DC_NOME            DC_NOME   object  ...          NaN          NaN
# PRE_INS            PRE_INS  float64  ...  1010.200000  1015.900000
# TEM_SEN            TEM_SEN  float64  ...    31.000000    37.600000
# VL_LATITUDE    VL_LATITUDE  float64  ...    -1.411228    -1.411228
# PRE_MAX            PRE_MAX  float64  ...  1010.500000  1016.000000
# UF                      UF   object  ...          NaN          NaN
# RAD_GLO            RAD_GLO  float64  ...  1147.381500  5230.005000
# PTO_INS            PTO_INS  float64  ...    23.600000    27.900000
# TEM_MIN            TEM_MIN  float64  ...    28.200000    35.600000
# VL_LONGITUDE  VL_LONGITUDE  float64  ...   -48.439512   -48.439512
# UMD_MIN            UMD_MIN  float64  ...    91.000000   100.000000
# PTO_MAX            PTO_MAX  float64  ...    24.100000    28.600000
# VEN_DIR            VEN_DIR  float64  ...   129.000000   360.000000
# DT_MEDICAO      DT_MEDICAO   object  ...          NaN          NaN
# CHUVA                CHUVA  float64  ...     0.000000    81.200000
# PRE_MIN            PRE_MIN  float64  ...  1009.900000  1015.700000
# UMD_MAX            UMD_MAX  float64  ...    92.000000   100.000000
# VEN_VEL            VEN_VEL  float64  ...     1.300000     7.200000
# PTO_MIN            PTO_MIN  float64  ...    23.200000    26.400000
# TEM_MAX            TEM_MAX  float64  ...    30.300000    38.500000
# VEN_RAJ            VEN_RAJ  float64  ...     5.100000    17.300000
# TEM_INS            TEM_INS  float64  ...    29.200000    37.000000
# UMD_INS            UMD_INS  float64  ...    92.000000   100.000000
# CD_ESTACAO      CD_ESTACAO   object  ...          NaN          NaN
# HR_MEDICAO      HR_MEDICAO    int64  ...  1725.000000  2300.000000
#
# [25 rows x 12 columns]

# %%
targets = ['TEM_INS','UMD_INS','VEN_VEL']

# %%
# !pip uninstall -y scipy
# Out:
# Found existing installation: scipy 1.7.3
# Uninstalling scipy-1.7.3:
#   Successfully uninstalled scipy-1.7.3

# %%
# !pip --no-cache-dir install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.1 MB)
#      |████████████████████████████████| 38.1 MB 1.4 MB/s
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /usr/local/lib/python3.7/dist-packages (from scipy) (1.19.5)
# Installing collected packages: scipy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed scipy-1.7.3

# %%
dados_float['DT_HR'] = dados_float.apply(lambda x: x['DT_MEDICAO'] + ' - ' + str(x['HR_MEDICAO']).zfill(4) , axis = 1)

# %%
from datetime import datetime

dados_float['DT_MEDICAO'] = dados_float['DT_MEDICAO'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d'))

# %%
dados_float_auto_arima = dados_float[dados_float['DT_MEDICAO'].dt.date < datetime.today().date() ].reset_index(drop=True)

dados_float_auto_arima = dados_float_auto_arima[dados_float_auto_arima['DT_MEDICAO'].dt.date >= datetime.strptime('2021-12-01', '%Y-%m-%d').date() ].reset_index(drop=True)

dados_float_auto_arima[targets] = dados_float_auto_arima[targets].apply(lambda x: x.fillna(x.mean()),axis=0)

# %%
dados_float_auto_arima
# Out:
#      DC_NOME  PRE_INS  TEM_SEN  ...  CD_ESTACAO  HR_MEDICAO              DT_HR
# 0      BELÉM   1006.8     29.9  ...        A201           0  2021-12-01 - 0000
# 1      BELÉM   1006.9     30.1  ...        A201         100  2021-12-01 - 0100
# 2      BELÉM   1007.2     30.3  ...        A201         200  2021-12-01 - 0200
# 3      BELÉM   1007.0     29.9  ...        A201         300  2021-12-01 - 0300
# 4      BELÉM   1006.4     29.9  ...        A201         400  2021-12-01 - 0400
# ...      ...      ...      ...  ...         ...         ...                ...
# 1147   BELÉM   1006.4     31.9  ...        A201        1900  2022-01-17 - 1900
# 1148   BELÉM   1006.5     32.7  ...        A201        2000  2022-01-17 - 2000
# 1149   BELÉM   1007.1     30.1  ...        A201        2100  2022-01-17 - 2100
# 1150   BELÉM   1007.7     29.0  ...        A201        2200  2022-01-17 - 2200
# 1151   BELÉM   1008.2     28.8  ...        A201        2300  2022-01-17 - 2300
#
# [1152 rows x 26 columns]

# %%
# !pip install pmdarima

# %%
import pmdarima as pm

results = []

for target in targets:

  model = pm.auto_arima(dados_float_auto_arima.loc[: ,target], 
                      start_p=1, d = 0, start_q=0,
                      test='adf',
                      max_p=2, max_d = 1, max_q=1, 
                      D = 1, start_Q = 0, max_P = 2, max_D = 1, max_Q = 0,
                      m=24,
                      seasonal=True, trace=True,
                      error_action='warn',  
                      suppress_warnings=True, 
                      stepwise=True, random_state = 1234)

  pred = model.predict(n_periods = 18*24)

  results.append(pred)

  print('\n')
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,0)(1,1,0)[24] intercept   : AIC=3693.047, Time=7.00 sec
#  ARIMA(0,0,0)(0,1,0)[24] intercept   : AIC=4614.260, Time=0.25 sec
#  ARIMA(0,0,1)(0,1,0)[24] intercept   : AIC=4145.192, Time=1.48 sec
#  ARIMA(0,0,0)(0,1,0)[24]             : AIC=4613.160, Time=0.18 sec
#  ARIMA(1,0,0)(0,1,0)[24] intercept   : AIC=3956.634, Time=0.75 sec
#  ARIMA(1,0,0)(2,1,0)[24] intercept   : AIC=3572.911, Time=21.12 sec
#  ARIMA(0,0,0)(2,1,0)[24] intercept   : AIC=4182.062, Time=15.16 sec
#  ARIMA(2,0,0)(2,1,0)[24] intercept   : AIC=3573.351, Time=25.50 sec
#  ARIMA(1,0,1)(2,1,0)[24] intercept   : AIC=3572.926, Time=24.75 sec
#  ARIMA(0,0,1)(2,1,0)[24] intercept   : AIC=3748.350, Time=16.93 sec
#  ARIMA(2,0,1)(2,1,0)[24] intercept   : AIC=3571.911, Time=67.93 sec
#  ARIMA(2,0,1)(1,1,0)[24] intercept   : AIC=inf, Time=40.95 sec
#  ARIMA(2,0,1)(2,1,0)[24]             : AIC=3570.628, Time=18.37 sec
#  ARIMA(2,0,1)(1,1,0)[24]             : AIC=inf, Time=18.07 sec
#  ARIMA(1,0,1)(2,1,0)[24]             : AIC=3571.789, Time=8.00 sec
#  ARIMA(2,0,0)(2,1,0)[24]             : AIC=3572.240, Time=6.01 sec
#  ARIMA(1,0,0)(2,1,0)[24]             : AIC=3571.875, Time=5.71 sec
#
# Best model:  ARIMA(2,0,1)(2,1,0)[24]
# Total fit time: 278.201 seconds
#
#
# Performing stepwise search to minimize aic
#  ARIMA(1,0,0)(1,1,0)[24] intercept   : AIC=7101.895, Time=7.60 sec
#  ARIMA(0,0,0)(0,1,0)[24] intercept   : AIC=8011.498, Time=0.24 sec
#  ARIMA(0,0,1)(0,1,0)[24] intercept   : AIC=7541.128, Time=1.75 sec
#  ARIMA(0,0,0)(0,1,0)[24]             : AIC=8010.125, Time=0.16 sec
#  ARIMA(1,0,0)(0,1,0)[24] intercept   : AIC=7325.892, Time=0.79 sec
#  ARIMA(1,0,0)(2,1,0)[24] intercept   : AIC=6980.007, Time=24.40 sec
#  ARIMA(0,0,0)(2,1,0)[24] intercept   : AIC=7658.906, Time=24.12 sec
#  ARIMA(2,0,0)(2,1,0)[24] intercept   : AIC=6980.818, Time=26.58 sec
#  ARIMA(1,0,1)(2,1,0)[24] intercept   : AIC=6980.664, Time=28.16 sec
#  ARIMA(0,0,1)(2,1,0)[24] intercept   : AIC=7199.374, Time=24.26 sec
#  ARIMA(2,0,1)(2,1,0)[24] intercept   : AIC=6980.748, Time=89.80 sec
#  ARIMA(1,0,0)(2,1,0)[24]             : AIC=6978.497, Time=4.93 sec
#  ARIMA(1,0,0)(1,1,0)[24]             : AIC=7100.178, Time=1.54 sec
#  ARIMA(0,0,0)(2,1,0)[24]             : AIC=7659.315, Time=3.59 sec
#  ARIMA(2,0,0)(2,1,0)[24]             : AIC=6979.278, Time=5.55 sec
#  ARIMA(1,0,1)(2,1,0)[24]             : AIC=6979.119, Time=6.41 sec
#  ARIMA(0,0,1)(2,1,0)[24]             : AIC=7198.903, Time=6.23 sec
#  ARIMA(2,0,1)(2,1,0)[24]             : AIC=6979.146, Time=21.45 sec
#
# Best model:  ARIMA(1,0,0)(2,1,0)[24]
# Total fit time: 277.592 seconds
#
#
# Performing stepwise search to minimize aic
#  ARIMA(1,0,0)(1,1,0)[24] intercept   : AIC=2067.599, Time=7.70 sec
#  ARIMA(0,0,0)(0,1,0)[24] intercept   : AIC=2640.216, Time=0.81 sec
#  ARIMA(0,0,1)(0,1,0)[24] intercept   : AIC=2433.430, Time=1.26 sec
#  ARIMA(0,0,0)(0,1,0)[24]             : AIC=2638.749, Time=0.18 sec
#  ARIMA(1,0,0)(0,1,0)[24] intercept   : AIC=2381.336, Time=0.80 sec
#  ARIMA(1,0,0)(2,1,0)[24] intercept   : AIC=1980.340, Time=27.80 sec
#  ARIMA(0,0,0)(2,1,0)[24] intercept   : AIC=2245.143, Time=16.88 sec
#  ARIMA(2,0,0)(2,1,0)[24] intercept   : AIC=1979.068, Time=27.04 sec
#  ARIMA(2,0,0)(1,1,0)[24] intercept   : AIC=2063.576, Time=9.09 sec
#  ARIMA(2,0,1)(2,1,0)[24] intercept   : AIC=1980.839, Time=91.91 sec
#  ARIMA(1,0,1)(2,1,0)[24] intercept   : AIC=1979.161, Time=37.73 sec
#  ARIMA(2,0,0)(2,1,0)[24]             : AIC=1977.246, Time=7.06 sec
#  ARIMA(2,0,0)(1,1,0)[24]             : AIC=2061.776, Time=2.39 sec
#  ARIMA(1,0,0)(2,1,0)[24]             : AIC=1978.534, Time=7.10 sec
#  ARIMA(2,0,1)(2,1,0)[24]             : AIC=1979.021, Time=20.97 sec
#  ARIMA(1,0,1)(2,1,0)[24]             : AIC=1977.338, Time=9.02 sec
#
# Best model:  ARIMA(2,0,0)(2,1,0)[24]
# Total fit time: 267.769 seconds

# %%
def allDays(ano, mes):
  '''Retorna uma lista com todos os dias de um determinado mes e ano'''
  
  return ['{:04d}-{:02d}-{:02d}'.format(ano, mes, dia) for dia in range(1, monthrange(ano, mes)[1] + 1)]

# %%
anos = [2022]
meses = [1, 2]
horas = [str(hora).zfill(4) for hora in range(0, 2400, 100)]

datas = sorted([ allDays(int(ano), int(mes)) for mes, ano in product(meses, anos) ])
datas = sum(datas, [])

datas = sorted([ f'{data} - {hora}' for data, hora in product(datas, horas)])

datas = datas[17*24: 17*24 + 18*24]

# %%
pred_date = pd.DataFrame({'DT_HR': datas, 'TEM_INS': results[0], 'UMD_INS': results[1],'VEN_VEL': results[2] })

# %%
pred_date[-24:].to_csv('predics_lmss.csv', index = False)
